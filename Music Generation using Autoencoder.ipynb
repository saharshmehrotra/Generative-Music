# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras import backend as K
import numpy as np
import os
import pickle

class Autoencoder:
    def __init__(self, input_shape, conv_filters, conv_kernels, conv_strides, latent_space_dim):
        self.input_shape = input_shape  # [w, h, c]
        self.conv_filters = conv_filters  # []
        self.conv_kernels = conv_kernels  # []
        self.conv_strides = conv_strides  # []
        self.latent_space_dim = latent_space_dim  # int
        self._num_conv_layers = len(conv_filters)
        self.encoder = None
        self.decoder = None
        self.model = None
        self._shape_before_bottleneck = None
        self._model_input = None
        self._build()

    def summary(self):
        self.encoder.summary()
        self.decoder.summary()
        self.model.summary()

    def _build(self):
        self._build_encoder()
        self._build_decoder()
        self._build_autoencoder()

    def _build_encoder(self):
        encoder_input = self._add_encoder_input()
        conv_layers = self._add_conv_layers(encoder_input)
        bottleneck = self._add_bottleneck(conv_layers)
        self._model_input = encoder_input
        self.encoder = Model(encoder_input, bottleneck, name="encoder")

    def _add_encoder_input(self):
        return layers.Input(shape=self.input_shape, name='encoder_input')

    def _add_conv_layers(self, encoder_input):
        x = encoder_input
        for layer_index in range(self._num_conv_layers):
            x = self._add_conv_layer(layer_index, x)
        return x

    def _add_conv_layer(self, layer_index, x):
        layer_number = layer_index + 1
        conv_layer = layers.Conv2D(filters=self.conv_filters[layer_index],
                                   kernel_size=self.conv_kernels[layer_index],
                                   strides=self.conv_strides[layer_index],
                                   padding="same",
                                   name=f"encoder_conv_layer_{layer_number}")
        x = conv_layer(x)
        x = layers.ReLU(name=f"encoder_relu_{layer_number}")(x)
        x = layers.BatchNormalization(name=f"encoder_bn_{layer_number}")(x)
        return x

    def _add_bottleneck(self, conv_layers):
        self._shape_before_bottleneck = K.int_shape(conv_layers)[1:]  # [batch_size, w, h, c] -> ignore batch_size
        x = layers.Flatten(name="bottleneck")(conv_layers)
        x = layers.Dense(self.latent_space_dim, name="encoder_output")(x)
        return x

    def _build_decoder(self):
        decoder_input = self._add_decoder_input()
        dense_layer = self._add_dense_layer(decoder_input)
        reshape_layer = self._add_reshape_layer(dense_layer)
        conv_transpose_layers = self._add_conv_transpose_layers(reshape_layer)
        decoder_output = self._add_decoder_output(conv_transpose_layers)
        self.decoder = Model(decoder_input, decoder_output, name="decoder")

    def _add_decoder_input(self):
        return layers.Input(shape=(self.latent_space_dim,), name="decoder_input")

    def _add_dense_layer(self, decoder_input):
        num_neurons = np.prod(self._shape_before_bottleneck)
        dense_layer = layers.Dense(num_neurons, name="decoder_dense")(decoder_input)
        return dense_layer

    def _add_reshape_layer(self, dense_layer):
        reshape_layer = layers.Reshape(target_shape=self._shape_before_bottleneck, name="decoder_reshape")(dense_layer)
        return reshape_layer

    def _add_conv_transpose_layers(self, reshape_layer):
        x = reshape_layer
        for layer_index in reversed(range(1, self._num_conv_layers)):
            x = self._add_conv_transpose_layer(layer_index, x)
        return x

    def _add_conv_transpose_layer(self, layer_index, x):
        layer_number = self._num_conv_layers - layer_index
        conv_transpose_layer = layers.Conv2DTranspose(filters=self.conv_filters[layer_index],
                                                      kernel_size=self.conv_kernels[layer_index],
                                                      strides=self.conv_strides[layer_index],
                                                      padding="same",
                                                      name=f"decoder_conv_transpose_layer_{layer_number}")
        x = conv_transpose_layer(x)
        x = layers.ReLU(name=f"decoder_relu_{layer_number}")(x)
        x = layers.BatchNormalization(name=f"decoder_bn_{layer_number}")(x)
        return x

    def _add_decoder_output(self, conv_transpose_layers):
        conv_transpose_layer = layers.Conv2DTranspose(filters=1,
                                                      kernel_size=self.conv_kernels[0],
                                                      strides=self.conv_strides[0],
                                                      padding="same",
                                                      name=f"decoder_conv_transpose_layer_{self._num_conv_layers}")
        x = conv_transpose_layer(conv_transpose_layers)
        output_layer = layers.Activation("sigmoid", name="sigmoid_layer")(x)
        return output_layer

    def _build_autoencoder(self):
        model_input = self._model_input
        model_output = self.decoder(self.encoder(model_input))
        self.model = Model(model_input, model_output, name="autoencoder")

    def compile(self, learning_rate=0.001):
        optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        mse_loss = tf.keras.losses.MeanSquaredError()
        self.model.compile(optimizer=optimizer, loss=mse_loss)

    def train(self, X_train, batch_size, epochs):
        self.model.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, shuffle=True)

    def save(self, save_folder="."):
        self._create_folder_if_it_doesnt_exist(save_folder)
        self._save_parameters(save_folder)
        self._save_weights(save_folder)

    def _create_folder_if_it_doesnt_exist(self, folder):
        if not os.path.exists(folder):
            os.makedirs(folder)

    def _save_parameters(self, save_folder):
        parameters = [
            self.input_shape,
            self.conv_filters,
            self.conv_kernels,
            self.conv_strides,
            self.latent_space_dim
        ]
        save_path = os.path.join(save_folder, "parameters.pkl")
        with open(save_path, "wb") as f:
            pickle.dump(parameters, f)

    def _save_weights(self, save_folder):
        save_path = os.path.join(save_folder, "weights.h5")
        self.model.save_weights(save_path)

    @classmethod
    def load(cls, save_folder="."):
        parameters_path = os.path.join(save_folder, "parameters.pkl")
        with open(parameters_path, "rb") as f:
            parameters = pickle.load(f)
        autoencoder = Autoencoder(*parameters)
        weights_path = os.path.join(save_folder, "weights.h5")
        autoencoder.load_weights(weights_path)
        return autoencoder

    def load_weights(self, weights_path):
        self.model.load_weights(weights_path)

    def reconstruct(self, images):
        latent_representations = self.encoder.predict(images)
        reconstructed_images = self.decoder.predict(latent_representations)
        return reconstructed_images, latent_representations


if __name__ == "__main__":
    autoencoder = Autoencoder(input_shape=(256, 752, 1),  # Adjusted input shape for 8-second samples
                              conv_filters=[32, 64, 128, 256],
                              conv_kernels=[3, 3, 3, 3],
                              conv_strides=[1, 2, 2, 2],  # Adjusted strides for larger input
                              latent_space_dim=128)  # Adjusted latent space dimension
    autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 256, 752, 1)]     0
#
#  encoder_conv_layer_1 (Conv  (None, 256, 752, 32)      320
#  2D)
#
#  encoder_relu_1 (ReLU)       (None, 256, 752, 32)      0
#
#  encoder_bn_1 (BatchNormali  (None, 256, 752, 32)      128
#  zation)
#
#  encoder_conv_layer_2 (Conv  (None, 128, 376, 64)      18496
#  2D)
#
#  encoder_relu_2 (ReLU)       (None, 128, 376, 64)      0
#
#  encoder_bn_2 (BatchNormali  (None, 128, 376, 64)      256
#  zation)
#
#  encoder_conv_layer_3 (Conv  (None, 64, 188, 128)      73856
#  2D)
#
#  encoder_relu_3 (ReLU)       (None, 64, 188, 128)      0
#
#  encoder_bn_3 (BatchNormali  (None, 64, 188, 128)      512
#  zation)
#
#  encoder_conv_layer_4 (Conv  (None, 32, 94, 256)       295168
#  2D)
#
#  encoder_relu_4 (ReLU)       (None, 32, 94, 256)       0
#
#  encoder_bn_4 (BatchNormali  (None, 32, 94, 256)       1024
#  zation)
#
#  bottleneck (Flatten)        (None, 770048)            0
#
#  encoder_output (Dense)      (None, 128)               98566272
#
# =================================================================
# Total params: 98956032 (377.49 MB)
# Trainable params: 98955072 (377.48 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 128)]             0
#
#  decoder_dense (Dense)       (None, 770048)            99336192
#
#  decoder_reshape (Reshape)   (None, 32, 94, 256)       0
#
#  decoder_conv_transpose_lay  (None, 64, 188, 256)      590080
#  er_1 (Conv2DTranspose)
#
#  decoder_relu_1 (ReLU)       (None, 64, 188, 256)      0
#
#  decoder_bn_1 (BatchNormali  (None, 64, 188, 256)      1024
#  zation)
#
#  decoder_conv_transpose_lay  (None, 128, 376, 128)     295040
#  er_2 (Conv2DTranspose)
#
#  decoder_relu_2 (ReLU)       (None, 128, 376, 128)     0
#
#  decoder_bn_2 (BatchNormali  (None, 128, 376, 128)     512
#  zation)
#
#  decoder_conv_transpose_lay  (None, 256, 752, 64)      73792
#  er_3 (Conv2DTranspose)
#
#  decoder_relu_3 (ReLU)       (None, 256, 752, 64)      0
#
#  decoder_bn_3 (BatchNormali  (None, 256, 752, 64)      256
#  zation)
#
#  decoder_conv_transpose_lay  (None, 256, 752, 1)       577
#  er_4 (Conv2DTranspose)
#
#  sigmoid_layer (Activation)  (None, 256, 752, 1)       0
#
# =================================================================
# Total params: 100297473 (382.60 MB)
# Trainable params: 100296577 (382.60 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 256, 752, 1)]     0
#
#  encoder (Functional)        (None, 128)               98956032
#
#  decoder (Functional)        (None, 256, 752, 1)       100297473
#
# =================================================================
# Total params: 199253505 (760.09 MB)
# Trainable params: 199251649 (760.08 MB)
# Non-trainable params: 1856 (7.25 KB)
# _________________________________________________________________

# %%
import numpy as np
import librosa
import os
import pickle

class Loader:
    """
    Loader is responsible for loading an audio file.
    """
    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              duration=self.duration,
                              mono=self.mono)[0] # returns a tuple: (signal, sample_rate)
        return signal


class Padder:
    """
    Padder is responsible for applying padding to an array.
    """
    def __init__(self, mode="constant"):
        self.mode = mode

    def left_pad(self, array, num_missing_items):
        """
        eg: [1,2,3] with 2 items -> [0,0,1,2,3]
        """
        padded_array = np.pad(array, (num_missing_items, 0), mode=self.mode) # insert/append num_missing_items at the beginning of the array
        return padded_array

    def right_pad(self, array, num_missing_items):
        """
        eg: [1,2,3] with 2 items -> [1,2,3,0,0]
        """
        padded_array = np.pad(array, (0, num_missing_items),
                              mode=self.mode)
        return padded_array


class LogSpectrogramExtractor:
    """
    Extracts Log Spectrograms (in dB) from a time-series signal.
    """
    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length

    def extract(self, signal):
        # short-time fourier transform
        stft = librosa.stft(signal, n_fft=self.frame_size, hop_length=self.hop_length)[:-1]  # (1 + (frame_size / 2), num_frames)
        spectrogram = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram


class MinMaxNormaliser:
    """
    Applies min-max normalization to an array. Using range [0,1].
    """
    def __init__(self, min_val, max_val):
        self.min_val = min_val
        self.max_val = max_val

    def normalise(self, array):
        normalised_array = (array - array.min()) / (array.max() - array.min()) # (x - xmin) / (xmax - xmin)
        normalised_array = normalised_array * (self.max_val - self.min_val) + self.min_val
        return normalised_array

    def denormalise(self, normalised_array, original_min_of_array, original_max_of_array):
        array = (normalised_array - self.min_val) / (self.max_val - self.min_val)
        array = array * (original_max_of_array - original_min_of_array) + original_min_of_array
        return array


class Saver:
    """
    Responsible for saving the features, and the min max values which will further be used during reconstruction.
    """
    def __init__(self, feature_save_dir, min_max_values_save_dir):
        self.feature_save_dir = feature_save_dir
        self.min_max_values_save_dir = min_max_values_save_dir
        self._ensure_dir_exists(self.feature_save_dir)
        self._ensure_dir_exists(self.min_max_values_save_dir)

    def save_feature(self, feature, file_path):
        save_path = self._generate_save_path(file_path)
        np.save(save_path, feature)
        return save_path

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1] # returns [head, tail]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path

    def save_min_max_values(self, min_max_values):
        save_path = os.path.join(self.min_max_values_save_dir, "min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(min_max_values, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(min_max_values, f)

    @staticmethod
    def _ensure_dir_exists(directory):
        if not os.path.exists(directory):
            os.makedirs(directory)


class PreprocessingPipeline:
    """
    Preprocesses the audio files in a directory, applying the following steps to each file:
        1. Load the file
        2. Pad the signal (if necessary)
        3. Extracting log spectrograms from the signal
        4. Normalize spectrogram
        5. Save the normalized spectrogram

    Storing the min max values for all the log spectrograms for reconstructing the signal.
    """
    def __init__(self, loader, padder, extractor, normaliser, saver):
        self.loader = loader
        self.padder = padder
        self.extractor = extractor
        self.normaliser = normaliser
        self.saver = saver
        self.min_max_values = {} # {save_path: {"min": min_val, "max": max_val}}
        self._num_expected_samples = int(loader.sample_rate * loader.duration)

    def preprocess(self, audio_file_dir):
        for root, _, files in os.walk(audio_file_dir):
            for file in files:
                file_path = os.path.join(root, file)
                try:
                    self._process_file(file_path)
                    print(f"Processed file: {file_path}")
                except Exception as e:
                    print(f"Could not process file {file_path}: {e}")
        self.saver.save_min_max_values(self.min_max_values)

    def _process_file(self, file_path):
        signal = self.loader.load(file_path)
        if self._is_padding_required(signal):
            signal = self._apply_padding(signal)
        feature = self.extractor.extract(signal)
        normalised_feature = self.normaliser.normalise(feature)
        save_path = self.saver.save_feature(normalised_feature, file_path)
        self._store_min_max_values(save_path, feature.min(), feature.max())

    def _is_padding_required(self, signal):
        return len(signal) < self._num_expected_samples

    def _apply_padding(self, signal):
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_values(self, save_path, min_val, max_val):
        self.min_max_values[save_path] = {
            "min": min_val,
            "max": max_val
        }

if __name__ == "__main__":
    FRAME_SIZE = 512
    HOP_LENGTH = 256
    DURATION = 5 # in seconds
    SAMPLE_RATE = 22050
    MONO = True

    # Relative paths
    SPECTOGRAMS_SAVE_DIR = os.path.join(os.getcwd(), "saved_data", "spectrograms")
    MIN_MAX_VALUES_SAVE_DIR = os.path.join(os.getcwd(), "saved_data", "min_max_values")
    AUDIO_FILES_DIR = r"C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original"

    # instantiate all objects
    loader = Loader(SAMPLE_RATE, DURATION, MONO)
    padder = Padder()
    log_spectrogram_extractor = LogSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
    min_max_normaliser = MinMaxNormaliser(0, 1)
    saver = Saver(SPECTOGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)

    # preprocessing pipeline
    preprocessing_pipeline = PreprocessingPipeline(loader, padder, log_spectrogram_extractor, min_max_normaliser, saver)

    preprocessing_pipeline.preprocess(AUDIO_FILES_DIR)
# Out:
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\0.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\1.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\2.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\3.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\4.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\blues\blues.00099.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\classical\classical.00099.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\country\country.00099.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\disco\disco.00099.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\hiphop\hiphop.00080.wav
# ...
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\reggae\reggae.00099.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00000.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00001.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00002.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00003.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00004.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00005.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00006.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00007.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00008.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00009.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00010.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00011.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00012.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00013.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00014.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00015.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00016.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00017.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00018.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00019.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00020.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00021.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00022.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00023.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00024.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00025.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00026.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00027.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00028.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00029.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00030.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00031.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00032.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00033.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00034.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00035.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00036.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00037.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00038.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00039.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00040.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00041.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00042.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00043.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00044.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00045.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00046.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00047.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00048.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00049.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00050.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00051.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00052.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00053.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00054.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00055.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00056.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00057.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00058.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00059.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00060.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00061.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00062.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00063.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00064.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00065.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00066.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00067.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00068.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00069.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00070.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00071.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00072.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00073.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00074.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00075.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00076.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00077.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00078.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00079.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00080.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00081.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00082.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00083.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00084.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00085.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00086.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00087.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00088.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00089.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00090.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00091.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00092.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00093.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00094.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00095.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00096.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00097.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00098.wav
# Processed file: C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original\rock\rock.00099.wav

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras import backend as K
import numpy as np
import os
import pickle

LEARNING_RATE = 0.001
BATCH_SIZE = 32
EPOCHS = 5
SPECTOGRAM_PATH = r"C:\Users\jmdgo\saved_data\spectrograms"
TARGET_SHAPE = (256, 752)


def load_fsdd(spectrograms_path, target_shape):
    x_train = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path)
            spectrogram = np.expand_dims(spectrogram, axis=-1)  # Add channel dimension
            if spectrogram.shape[:2] != target_shape:
                spectrogram = tf.image.resize(spectrogram, target_shape).numpy()
            x_train.append(spectrogram)
    x_train = np.array(x_train)
    return x_train


def train(x_train, learning_rate, batch_size, epochs):
    autoencoder = Autoencoder(
        input_shape=(256, 752, 1),
        conv_filters=(512, 256, 128, 64, 32),
        conv_kernels=(3, 3, 3, 3, 3),
        conv_strides=(2, 2, 2, 2, (2, 1)),
        latent_space_dim=128
    )
    autoencoder.summary()
    autoencoder.compile(learning_rate)
    autoencoder.train(x_train, batch_size, epochs)
    return autoencoder


if __name__ == "__main__":
    x_train = load_fsdd(SPECTOGRAM_PATH, TARGET_SHAPE)
    autoencoder = train(x_train, LEARNING_RATE, BATCH_SIZE, EPOCHS)
    autoencoder.save("model")
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 256, 752, 1)]     0
#
#  encoder_conv_layer_1 (Conv  (None, 128, 376, 512)     5120
#  2D)
#
#  encoder_relu_1 (ReLU)       (None, 128, 376, 512)     0
#
#  encoder_bn_1 (BatchNormali  (None, 128, 376, 512)     2048
#  zation)
#
#  encoder_conv_layer_2 (Conv  (None, 64, 188, 256)      1179904
#  2D)
#
#  encoder_relu_2 (ReLU)       (None, 64, 188, 256)      0
#
#  encoder_bn_2 (BatchNormali  (None, 64, 188, 256)      1024
#  zation)
#
#  encoder_conv_layer_3 (Conv  (None, 32, 94, 128)       295040
#  2D)
#
#  encoder_relu_3 (ReLU)       (None, 32, 94, 128)       0
#
#  encoder_bn_3 (BatchNormali  (None, 32, 94, 128)       512
#  zation)
#
#  encoder_conv_layer_4 (Conv  (None, 16, 47, 64)        73792
#  2D)
#
#  encoder_relu_4 (ReLU)       (None, 16, 47, 64)        0
#
#  encoder_bn_4 (BatchNormali  (None, 16, 47, 64)        256
#  zation)
#
#  encoder_conv_layer_5 (Conv  (None, 8, 47, 32)         18464
#  2D)
#
#  encoder_relu_5 (ReLU)       (None, 8, 47, 32)         0
#
#  encoder_bn_5 (BatchNormali  (None, 8, 47, 32)         128
#  zation)
#
#  bottleneck (Flatten)        (None, 12032)             0
#
#  encoder_output (Dense)      (None, 128)               1540224
#
# =================================================================
# Total params: 3116512 (11.89 MB)
# Trainable params: 3114528 (11.88 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 128)]             0
#
#  decoder_dense (Dense)       (None, 12032)             1552128
#
#  decoder_reshape (Reshape)   (None, 8, 47, 32)         0
#
#  decoder_conv_transpose_lay  (None, 16, 47, 32)        9248
#  er_1 (Conv2DTranspose)
#
#  decoder_relu_1 (ReLU)       (None, 16, 47, 32)        0
#
#  decoder_bn_1 (BatchNormali  (None, 16, 47, 32)        128
#  zation)
#
#  decoder_conv_transpose_lay  (None, 32, 94, 64)        18496
#  er_2 (Conv2DTranspose)
#
#  decoder_relu_2 (ReLU)       (None, 32, 94, 64)        0
#
#  decoder_bn_2 (BatchNormali  (None, 32, 94, 64)        256
#  zation)
#
#  decoder_conv_transpose_lay  (None, 64, 188, 128)      73856
#  er_3 (Conv2DTranspose)
#
#  decoder_relu_3 (ReLU)       (None, 64, 188, 128)      0
#
#  decoder_bn_3 (BatchNormali  (None, 64, 188, 128)      512
#  zation)
#
#  decoder_conv_transpose_lay  (None, 128, 376, 256)     295168
#  er_4 (Conv2DTranspose)
#
#  decoder_relu_4 (ReLU)       (None, 128, 376, 256)     0
#
#  decoder_bn_4 (BatchNormali  (None, 128, 376, 256)     1024
#  zation)
#
#  decoder_conv_transpose_lay  (None, 256, 752, 1)       2305
#  er_5 (Conv2DTranspose)
#
#  sigmoid_layer (Activation)  (None, 256, 752, 1)       0
#
# =================================================================
# Total params: 1953121 (7.45 MB)
# Trainable params: 1952161 (7.45 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 256, 752, 1)]     0
#
#  encoder (Functional)        (None, 128)               3116512
#
#  decoder (Functional)        (None, 256, 752, 1)       1953121
#
# =================================================================
# Total params: 5069633 (19.34 MB)
# Trainable params: 5066689 (19.33 MB)
# Non-trainable params: 2944 (11.50 KB)
# _________________________________________________________________
# Epoch 1/5
# 32/32 [==============================] - 644s 19s/step - loss: 0.0418
# Epoch 2/5
# 32/32 [==============================] - 579s 18s/step - loss: 0.0185
# Epoch 3/5
# 32/32 [==============================] - 584s 18s/step - loss: 0.0134
# Epoch 4/5
# 32/32 [==============================] - 555s 17s/step - loss: 0.0122
# Epoch 5/5
# 32/32 [==============================] - 555s 17s/step - loss: 0.0119

# %%
class SoundGenerator:
    """
    SoundGenerator is responsible for generating audios from spectograms
    """
    def __init__(self, ae, hop_length):
        self.ae = ae
        self.hop_length = hop_length
        self._min_max_normaliser = MinMaxNormaliser(0, 1)

    def generate(self, spectograms, min_max_values):
        generated_spectograms, latent_representations = self.ae.reconstruct(spectograms)
        signals = self.convert_spectograms_to_audio(generated_spectograms, min_max_values)
        return signals, latent_representations

    def convert_spectograms_to_audio(self, spectograms, min_max_values):
        signals = []
        for spectogram, min_max_value in zip(spectograms, min_max_values):
            # reshape the log spectogram
            log_spectogram = spectogram[:,:,0]
            # apply denormalisation
            denormalised_log_spec = self._min_max_normaliser.denormalise(log_spectogram,
                                                                          min_max_value["min"], min_max_value["max"])
            # log spectogram -> spectogram
            spec = librosa.db_to_amplitude(denormalised_log_spec)
            # apply Griffin-Lim algorithm (used inverse short-time fourier transform)
            signal = librosa.istft(spec, hop_length=self.hop_length)
            # append signal to signals list
            signals.append(signal)

        return signals

# %%
import os
import pickle
import numpy as np
import soundfile as sf

HOP_LENGTH = 256
SAVE_DIR_ORIGINAL = r"C:\Users\jmdgo\Downloads\archive (9)\Data\genres_original"
SAVE_DIR_GENERATED = r"C:\Users\jmdgo\saved_data\samples\generated"
MIN_MAX_VALUES_PATH = r"C:\Users\jmdgo\saved_data\min_max_values\min_max_values.pkl"

def load_fsdd(spectrograms_path, target_shape=(256, 752)):
    x_train = []
    file_paths = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path)
            spectrogram = adjust_spectrogram_shape(spectrogram, target_shape)
            x_train.append(spectrogram)
            file_paths.append(file_path)
    x_train = np.array(x_train)
    x_train = x_train[..., np.newaxis]
    return x_train, file_paths

def adjust_spectrogram_shape(spectrogram, target_shape):
    target_bins, target_frames = target_shape
    bins, frames = spectrogram.shape

    if bins < target_bins:
        pad_bins = target_bins - bins
        spectrogram = np.pad(spectrogram, ((0, pad_bins), (0, 0)), mode='constant')
    elif bins > target_bins:
        spectrogram = spectrogram[:target_bins, :]

    if frames < target_frames:
        pad_frames = target_frames - frames
        spectrogram = np.pad(spectrogram, ((0, 0), (0, pad_frames)), mode='constant')
    elif frames > target_frames:
        spectrogram = spectrogram[:, :target_frames]

    return spectrogram

def select_spectrograms(spectrograms, file_paths, min_max_values, num_spectrograms=2):
    sampled_indexes = np.random.choice(range(len(spectrograms)), num_spectrograms)
    sampled_spectrograms = spectrograms[sampled_indexes]
    file_paths = [file_paths[index] for index in sampled_indexes]
    sampled_min_max_values = [min_max_values[file_path] for file_path in file_paths]
    print(file_paths)
    print(sampled_min_max_values)
    return sampled_spectrograms, sampled_min_max_values

def save_signals(signals, save_dir, sample_rate=22050):
    os.makedirs(save_dir, exist_ok=True)
    for i, signal in enumerate(signals):
        save_path = os.path.join(save_dir, str(i) + ".wav")
        sf.write(save_path, signal, sample_rate)

if __name__ == "__main__":
    # initialise sound generator
    ae = Autoencoder.load("model")
    sound_generator = SoundGenerator(ae, HOP_LENGTH)

    # load spectrograms + min max values
    with open(MIN_MAX_VALUES_PATH, "rb") as f:
        min_max_values = pickle.load(f)

    specs, file_paths = load_fsdd(SPECTOGRAM_PATH)

    # sample spectrograms + min max values
    sampled_specs, sampled_min_max_values = select_spectrograms(specs, file_paths, min_max_values, 5)

    # generate audio for sampled spectrograms
    signals, _ = sound_generator.generate(sampled_specs, sampled_min_max_values)

    # convert spectrogram samples to audio
    original_signals = sound_generator.convert_spectograms_to_audio(sampled_specs, sampled_min_max_values)

    # save audio signals
    save_signals(signals, SAVE_DIR_GENERATED)
    save_signals(original_signals, SAVE_DIR_ORIGINAL)
# Out:
# ['C:\\Users\\jmdgo\\saved_data\\spectrograms\\pop.00027.wav.npy', 'C:\\Users\\jmdgo\\saved_data\\spectrograms\\country.00003.wav.npy', 'C:\\Users\\jmdgo\\saved_data\\spectrograms\\reggae.00020.wav.npy', 'C:\\Users\\jmdgo\\saved_data\\spectrograms\\hiphop.00077.wav.npy', 'C:\\Users\\jmdgo\\saved_data\\spectrograms\\jazz.00040.wav.npy']
# [{'min': -44.167793, 'max': 35.832207}, {'min': -43.159996, 'max': 36.840004}, {'min': -44.82614, 'max': 35.17386}, {'min': -39.559013, 'max': 40.440987}, {'min': -49.608997, 'max': 30.391003}]
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 759ms/step

# %%
autoencoder.save(r"C:\Users\jmdgo\saved_data")
